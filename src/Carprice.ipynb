# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("car_price_prediction.csv")

# %%
df.head(6)
# Out:
#          ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS    RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET   Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA       FIT        2006  Hatchback
# 3  45769185   3607   862         FORD    Escape        2011       Jeep
# 4  45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5  45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
# 5              Yes    Diesel             2  160931 km        4.0
#
# ...

# %%
df.shape
# Out:
# (19237, 18)

# %%
df["Levy"].replace("-",np.nan,inplace=True)
df["Levy"].isna().sum()
# Out:
# 5819

# %%
df["Engine volume"].replace("0",np.nan,inplace=True)
df["Engine volume"].isna().sum()
# Out:
# 10

# %%
df.dropna()
# Out:
#              ID  Price  Levy   Manufacturer     Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS    RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET   Equinox        2011       Jeep
# 3      45769185   3607   862           FORD    Escape        2011       Jeep
# 4      45809263  11726   446          HONDA       FIT        2014  Hatchback
# 5      45802912  39493   891        HYUNDAI  Santa FE        2016       Jeep
# ...         ...    ...   ...            ...       ...         ...        ...
# 19231  45772306   5802  1055  MERCEDES-BENZ     E 350        2013      Sedan
# 19233  45778856  15681   831        HYUNDAI    Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI    Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET   Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI    Sonata        2012      Sedan
#
# ...

# %%
manufacturer_to_country = {
    "HYUNDAI": "South Korea",
    "TOYOTA": "Japan",
    "MERCEDES-BENZ": "Germany",
    "CHEVROLET": "United States",
    "LEXUS": "Japan",
    "FORD": "United States",
    "HONDA": "Japan",
    "BMW": "Germany",
    "SSANGYONG": "South Korea",
    "KIA": "South Korea",
    "NISSAN": "Japan",
    "VOLKSWAGEN": "Germany",
    "AUDI": "Germany",
    "SUBARU": "Japan",
    "MAZDA": "Japan",
    "JEEP": "United States",
    "DAEWOO": "South Korea",
    "OPEL": "Germany",
    "MITSUBISHI": "Japan",
    "DODGE": "United States",
    "FIAT": "Italy",
    "JAGUAR": "United Kingdom",
    "PORSCHE": "Germany",
    "MINI": "United Kingdom",
    "SUZUKI": "Japan",
    "LAND ROVER": "United Kingdom",
    "CHRYSLER": "United States",
    "BUICK": "United States",
    "GMC": "United States",
    "ACURA": "Japan",
    "RENAULT": "France",
    "CADILLAC": "United States",
    "INFINITI": "Japan",
    "LINCOLN": "United States",
    "VOLVO": "Sweden",
    "CITROEN": "France",
    "MERCURY": "United States",
    "MASERATI": "Italy",
    "DAIHATSU": "Japan",
    "FERRARI": "Italy",
    "SCION": "Japan",
    "PEUGEOT": "France",
    "VAZ": "Russia",
    "SKODA": "Czech Republic",
    "LAMBORGHINI": "Italy",
    "BENTLEY": "United Kingdom",
    "GAZ": "Russia",
    "TESLA": "United States",
    "HUMMER": "United States"
}

# %%
# Adding the 'Country' column to the DataFrame
df['Country'] = df['Manufacturer'].map(manufacturer_to_country)

print(df)
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467   NaN          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467   NaN  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df.head(10)
# Out:
#          ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS    RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET   Equinox        2011       Jeep
# 2  45774419   8467   NaN        HONDA       FIT        2006  Hatchback
# 3  45769185   3607   862         FORD    Escape        2011       Jeep
# 4  45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5  45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
# 6  45656768   1803   761       TOYOTA     Prius        2010  Hatchback
# 7  45816158    549   751      HYUNDAI    Sonata        2013      Sedan
# 8  45641395   1098   394       TOYOTA     Camry        2014      Sedan
# 9  45756839  26657   NaN        LEXUS    RX 350        2007       Jeep
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# ...

# %%
df=df.dropna()

# %%
df.head(10)
# Out:
#           ID  Price  Levy   Manufacturer     Model  Prod. year   Category  \
# 0   45654403  13328  1399          LEXUS    RX 450        2010       Jeep
# 1   44731507  16621  1018      CHEVROLET   Equinox        2011       Jeep
# 3   45769185   3607   862           FORD    Escape        2011       Jeep
# 4   45809263  11726   446          HONDA       FIT        2014  Hatchback
# 5   45802912  39493   891        HYUNDAI  Santa FE        2016       Jeep
# 6   45656768   1803   761         TOYOTA     Prius        2010  Hatchback
# 7   45816158    549   751        HYUNDAI    Sonata        2013      Sedan
# 8   45641395   1098   394         TOYOTA     Camry        2014      Sedan
# 10  45621750    941  1053  MERCEDES-BENZ     E 350        2014      Sedan
# 13  45661288   1019  1055          LEXUS    RX 450        2013       Jeep
#
#    Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0               Yes    Hybrid           3.5  186005 km        6.0
# ...

# %%
df['Mileage'] = df['Mileage'].str.replace('km', '').astype(int)
df['Engine volume'] = df['Engine volume'].str.replace('Turbo', '').astype(float)

# %%
df['Condition'] = np.where(df['Mileage'] == 0, 'Brand_New', 'Used')

# %%
df.head(10)
# Out:
#           ID  Price  Levy   Manufacturer     Model  Prod. year   Category  \
# 0   45654403  13328  1399          LEXUS    RX 450        2010       Jeep
# 1   44731507  16621  1018      CHEVROLET   Equinox        2011       Jeep
# 3   45769185   3607   862           FORD    Escape        2011       Jeep
# 4   45809263  11726   446          HONDA       FIT        2014  Hatchback
# 5   45802912  39493   891        HYUNDAI  Santa FE        2016       Jeep
# 6   45656768   1803   761         TOYOTA     Prius        2010  Hatchback
# 7   45816158    549   751        HYUNDAI    Sonata        2013      Sedan
# 8   45641395   1098   394         TOYOTA     Camry        2014      Sedan
# 10  45621750    941  1053  MERCEDES-BENZ     E 350        2014      Sedan
# 13  45661288   1019  1055          LEXUS    RX 450        2013       Jeep
#
#    Leather interior Fuel type  Engine volume  Mileage  Cylinders  \
# 0               Yes    Hybrid            3.5   186005        6.0
# ...

# %% [markdown]
# Replace the 4-may and 2-may to 4-5 and 2-3

# %%
df["Doors"].replace("04-May","4-5",inplace=True)
df["Doors"].replace("02-May","2-3",inplace=True)

# %%
df.head(10)
# Out:
#           ID  Price  Levy   Manufacturer     Model  Prod. year   Category  \
# 0   45654403  13328  1399          LEXUS    RX 450        2010       Jeep
# 1   44731507  16621  1018      CHEVROLET   Equinox        2011       Jeep
# 3   45769185   3607   862           FORD    Escape        2011       Jeep
# 4   45809263  11726   446          HONDA       FIT        2014  Hatchback
# 5   45802912  39493   891        HYUNDAI  Santa FE        2016       Jeep
# 6   45656768   1803   761         TOYOTA     Prius        2010  Hatchback
# 7   45816158    549   751        HYUNDAI    Sonata        2013      Sedan
# 8   45641395   1098   394         TOYOTA     Camry        2014      Sedan
# 10  45621750    941  1053  MERCEDES-BENZ     E 350        2014      Sedan
# 13  45661288   1019  1055          LEXUS    RX 450        2013       Jeep
#
#    Leather interior Fuel type  Engine volume  Mileage  Cylinders  \
# 0               Yes    Hybrid            3.5   186005        6.0
# ...

# %%
df.to_csv('new_carprices.csv', index=False)
